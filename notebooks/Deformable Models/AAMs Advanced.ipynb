# %% [markdown]
# # Active Appearance Models - Advanced

# %% [markdown]
# -----

# %% [markdown]
# ## 1 Introduction

# %% [markdown]
# The aim of this notebook is to showcase some of the more advanced features that are available for building and fitting AAMs using `Menpo`.
#
# Note that this notebook assumes that the user has previously gone through the AAMs Basic notebook and he/she is already familiar with the basic AAMs and `Menpo` concepts explained in there.

# %% [markdown]
# ### 1.1 Building and fitting more flexible and powerful AAMs

# %% [markdown]
# The AAMs Basic notebook shows us how through the use of the `AAMBuilder` and the `LucasKanadeAAMFitter` classes one can easily build and fit basic AAMs using `Menpo`. In reality, `Menpo`'s framework for AAMs is a lot more powerful and we will proceed to show how a large variety of different AAMs and different fitting algorithm can be used by simply specifying the right keyword arguments on the two previous classes.
#
# The complete list of the available keyword arguments for both `AAMBuilder` and `LucasKanadeAAMFitter` and their corresponding detailed explainations can be found in Menpo's documentation. Remember that their documentation can be checked at any time from the IPython Notebook by simply running:

# %%
from menpo.fitmultilevel.aam import AAMBuilder

AAMBuilder??

# %%
from menpo.fitmultilevel.aam import LucasKanadeAAMFitter

LucasKanadeAAMFitter??

# %% [markdown]
# This notebook is structured in several shorts sections, each one explaining a different advanced concept related to `Menpo`'s framework for building and fitting AAMs.
#
# For example, the very first section explains how AAMs can be build using different appearance features (including arbitrarily apperance features defined by the user). Future section will tackle:
#
# * How to use different `LucasKanade` based algorithm for fitting AAMs.
# * How AAMs can also be fitted using `Menpo`'s Supervised Descent framework for cascade-regression.
# * ...
#
# Note that, in generael, these section will be fairly detached from one another and the orther in which they are listed bellow is not specifically rellevant.

# %% [markdown]
# ### 1.2 Acquiring data

# %% [markdown]
# However, all of them will rely on some training and testing data to build and fit their respective AAMs. Once again, we will rely on the training and test sets of the LFPW database for this purpose.
#
# Note that the necessary steps required for acquiring the LFPW database are explained in detail in the AAMs Basics notebook and the user is simply referred to that notebook for this matter.

# %%
path_to_lfpw = '/Users/joan/PhD/DataBases/'

# %% [markdown]
# Training data:

# %%
import menpo.io as mio

training_images = []
# load landmarked images
for i in mio.import_images(path_to_lfpw + 'lfpw/trainset/*.png'):
    # crop image
    i.crop_to_landmarks_proportion(0.1)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    training_images.append(i)

# %%
import matplotlib.pyplot as plt
from IPython.html.widgets import interact

def browse_images(images, group=None, label='all'):
    n = len(images)
    def view_image(i):
        images[i].landmarks[group][label].view()
        plt.show()
    interact(view_image, i=(0,n-1))

# %%
# %matplotlib inline

browse_images(training_images)

# %% [markdown]
# Test data:

# %%
import menpo.io as mio

# load test images
test_images = []
for i in mio.import_images(path_to_lfpw + 'lfpw/testset/*.png', max_images=5):
    # crop image
    i.crop_to_landmarks_proportion(0.5)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    test_images.append(i)

# %%
import matplotlib.pyplot as plt
from IPython.html.widgets import interact

def browse_images(images, group=None, label='all'):
    n = len(images)
    def view_image(i):
        images[i].landmarks[group][label].view()
        plt.show()
    interact(view_image, i=(0,n-1))

# %%
# %matplotlib inline

browse_images(test_images)

# %% [markdown]
# ## 2. Building and fitting AAMs with user-defined appearance features

# %% [markdown]
# One of the most powerful and general characteristics of the `AAMBuilder` class is that it allows the user to build AAMs with arbitrarily user-defined appearance features. Instead of restricting the user to a set of predifine appearance features, `Menpo` allows him/her to define new features (perhaps simple combinations of existing image features suported by Menpo or perhaps completely new (even discriminative!) features designed by the user) and pass them to the `AAMbuilder`.
#
# All that is required is that the user encapsulates his/her desired feature computation in an function that receives as an arguments a `Menpo` `Image` objects and that returns a `Menpo` `Image` object containing the desired features. The next cell shows a simple example of such a function, in which **igo** features are computed on an feature image that was already obtained by computing **igo** features:

# %%
def my_new_features(image):
    return image.features.igo().features.igo()

# %% [markdown]
# In order to build an AAM that uses the previous function to generate the appearance representation used by its apperance model we will first need to import some annotated images from which to build the AAM. Once again, we will use the LFPW training set for this purpose.
#
# Note that the necessary steps required for acquiring the LFPW dataset used throughout this notebook were previously explained in the AAMs Basics notebook and we simply refer the user to that notebook for this matter.

# %%
from menpo.fitmultilevel.aam import AAMBuilder

aam = AAMBuilder(feature_type=my_new_features, normalization_diagonal=100).build(training_images, verbose=True)
# Out:
# - Computing reference shape
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# ...

# %%
print aam
# Out:
# Active Appearance Model
#  - 811 training images.
#  - Warp using CachedPWA transform with 'scipy' interpolation.
#  - Gaussian pyramid with 3 levels and downscale factor of 2.
#    - Each level has a scaled shape model (reference frame).
#    - Pyramid was applied on feature space.
#    - Feature is my_new_features with 4 channels per image.
#    - Level 1 (no downscale):
#      - Reference frame of length 14836 (3709 x 4C, 75W x 74H x 4C)
#      - 133 shape components (100.00% of variance)
#      - 810 appearance components (100.00% of variance)
#    - Level 2 (downscale by 2):
#      - Reference frame of length 3692 (923 x 4C, 41W x 40H x 4C)
#      - 133 shape components (100.00% of variance)
#      - 810 appearance components (100.00% of variance)
#    - Level 3 (downscale by 4):
#      - Reference frame of length 908 (227 x 4C, 24W x 23H x 4C)
#      - 133 shape components (100.00% of variance)
#      - 810 appearance components (100.00% of variance)

# %%
def visualize_aam(aam, level=-1, bounds=(-3.0, 3.0), channels=None):    
    def view_aam(shape_pc1, shape_pc2, shape_pc3, tex_pc1, tex_pc2, tex_pc3):
        instance = aam.instance(shape_weights=[shape_pc1, shape_pc2, shape_pc3], 
                                appearance_weights=[tex_pc1, tex_pc2, tex_pc3],
                                level=level)
        instance.landmarks.view(channels=channels)
        plt.show()
    interact(view_aam, shape_pc1=bounds, shape_pc2=bounds, shape_pc3=bounds, tex_pc1=bounds, tex_pc2=bounds, tex_pc3=bounds)

# %%
# %matplotlib inline

visualize_aam(aam, channels=0)

# %%
from menpo.fitmultilevel.aam import LucasKanadeAAMFitter

fitter = LucasKanadeAAMFitter(aam, n_shape=[3, 6, 12], n_appearance=0.5)
print fitter
# Out:
# Active Appearance Model Fitter
#  - Lucas-Kanade Alternating-IC
#  - Transform is OrthoMDTransform and residual is SSD.
#  - 811 training images.
#  - Gaussian pyramid with 3 levels and downscale factor of 2.
#    - Each level has a scaled shape model (reference frame).
#    - Pyramid was applied on feature space.
#    - Feature is my_new_features with 4 channels per image.
#    - Level 1 (no downscale):
#      - Reference frame of length 14836 (3709 x 4C, 75W x 74H x 4C)
#      - 16 motion components
#      - 205 active appearance components (50.13% of original variance)
#    - Level 2 (downscale by 2):
#      - Reference frame of length 3692 (923 x 4C, 41W x 40H x 4C)
#      - 10 motion components
#      - 116 active appearance components (50.08% of original variance)
#    - Level 3 (downscale by 4):
#      - Reference frame of length 908 (227 x 4C, 24W x 23H x 4C)
#      - 7 motion components
#      - 47 active appearance components (50.15% of original variance)

# %%
fitting_results = []
# fit images
for j, i in enumerate(test_images):
    # obtain original landmarks
    gt_s = i.landmarks['PTS'].lms
    # generate perturbed landmarks
    s = fitter.perturb_shape(gt_s)
    # fit image
    fr = fitter.fit(i, s, gt_shape=gt_s) 
    # append fitting result to list
    fitting_results.append(fr)
    # print fitting information
    print 'Image: ', j
    print fr
# Out:
# Image:  0
# Initial error: 0.0748
# Final error: 0.0167
# Image:
#  1
# Initial error: 0.0321
# Final error: 0.0177
# Image:
#  2
# Initial error: 0.0784
# Final error: 0.0372
# Image:
#  3
# Initial error: 0.1348
# Final error: 0.0165
# Image:
#  4
# Initial error: 0.1151
# Final error: 0.0907

# %%
# %matplotlib inline

fitted_images = [fr.final_fitting for fr in fitting_results]
browse_images(fitted_images, group='fitted')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-e752d6ec742f> in <module>()
#       1 get_ipython().magic(u'matplotlib inline')
#       2
# ----> 3 fitted_images = [fr.final_fitting for fr in fitting_results]
#       4 browse_images(fitted_images, group='fitted')
#
# AttributeError: 'AAMMultilevelFittingResult' object has no attribute 'final_fitting'

# %% [markdown]
# ## 3. Fitting AAMs using different `LucasKanade` based algorithms.

# %% [markdown]
# `Menpo's` `LucasKanadeAAMFitter` objects can be set up to fit using a large variety of `LucasKanade` based algorithm for fitting AAMs. As shown on the AAMs Basics notebook, the default algorithm is the well known `Alternating Inverse Compositional` algorithm. The complete list of available algorithms implemented and with corresponding links to their rellevant references is listed below:
#
# * AlternatingForwardAdditive
# * AlternatingForwardCompositional
# * AlternatingInverseCompositional [6](http://ibug.doc.ic.ac.uk/media/uploads/documents/accv2012finalpaper.pdf)
# [2](http://ibug.doc.ic.ac.uk/media/uploads/documents/tzimiro_pantic_iccv2013.pdf)
#
#
# * ProjectOutForwardAdditive [1](http://gravis.cs.unibas.ch/publications/2009/CVPR09_Amberg.pdf)
# [2](http://ibug.doc.ic.ac.uk/media/uploads/documents/tzimiro_pantic_iccv2013.pdf)
# * ProjectOutForwardCompositional [1](http://gravis.cs.unibas.ch/publications/2009/CVPR09_Amberg.pdf)
# * ProjectOutInverseCompositional [1](http://gravis.cs.unibas.ch/publications/2009/CVPR09_Amberg.pdf)
#
#
# * SimultaneousForwardAdditive
# * SimultaneousForwardCompositional
# * SimultaneousInverseCompositional [3](http://www.ri.cmu.edu/pub_files/pub4/gross_ralph_2005_2/gross_ralph_2005_2.pdf)
#
#
# * AdaptiveForwardAdditive
# * AdaptiveForwardCompositional
# * AdaptiveInverseCompositional [4](http://www.stat.ucla.edu/~gpapan/pubs/confr/PapandreouMaragos_AAM_ieee-c-cvpr08.pdf)
#
#
# * BayesianForwardAdditive
# * BayesianForwardCompositional [5] a link to my paper
# * BayesianInverseCompositional
#
# Note that an effor has been made to generalize the original algorithms to support the common `Forward Additive`, `Forward Compositional` and `Inverse Compositional` paradigms.
#
# For a further details on the algorithms the user is referred to the refences an to their actual implementations in `Menpo`.

# %% [markdown]
# The first step to fit an AAM using a particular `LucasKanade` based fitting algorithm is to build an AAM:

# %%
from menpo.fitmultilevel.aam import AAMBuilder

aam = AAMBuilder(normalization_diagonal=100).build(training_images, verbose=True)
# Out:
# - Computing reference shape
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# ...

# %% [markdown]
# Note that the previous cell has built a multilevel AAM with 3 levels using **igo** features as the apperance representation of its 3 apperance models.

# %%
print aam
# Out:
# Active Appearance Model
#  - 811 training images.
#  - Warp using CachedPWA transform with 'scipy' interpolation.
#  - Gaussian pyramid with 3 levels and downscale factor of 2.
#    - Each level has a scaled shape model (reference frame).
#    - Pyramid was applied on feature space.
#    - Feature is igo with 2 channels per image.
#    - Level 1 (no downscale):
#      - Reference frame of length 7418 (3709 x 2C, 75W x 74H x 2C)
#      - 133 shape components (100.00% of variance)
#      - 810 appearance components (100.00% of variance)
#    - Level 2 (downscale by 2):
#      - Reference frame of length 1846 (923 x 2C, 41W x 40H x 2C)
#      - 133 shape components (100.00% of variance)
#      - 810 appearance components (100.00% of variance)
#    - Level 3 (downscale by 4):
#      - Reference frame of length 454 (227 x 2C, 24W x 23H x 2C)
#      - 133 shape components (100.00% of variance)
#      - 454 appearance components (100.00% of variance)

# %% [markdown]
# In order to fit the previous AAM using using one of the previous `LucasKanade` based algorithm the user is simply required to:
#
# * Import the algorithm that he/she wants to use.
# * Simply change the default value of the `algorithm` keyword argument on the `LucasKanadeAAMFitter` call.
#
# Note that all `LucasKanade` based fitting algorithm can be imported from `menpo.fit.lucaskanade.appearance`
#
# An example using the `ProjectOutInverseCompositional` algorithm is set on the next cell. AAMs can be made to fit any of the other `LucasKanade` algorithm in a similar manner.

# %%
from menpo.fit.lucaskanade.appearance import ProjectOutInverseCompositional

fitter = LucasKanadeAAMFitter(aam, algorithm=ProjectOutInverseCompositional,
                              n_shape=[3, 6, 12], n_appearance=0.5)
print fitter
# Out:
# Active Appearance Model Fitter
#  - Lucas-Kanade ProjectOut-IC
#  - Transform is OrthoMDTransform and residual is SSD.
#  - 811 training images.
#  - Gaussian pyramid with 3 levels and downscale factor of 2.
#    - Each level has a scaled shape model (reference frame).
#    - Pyramid was applied on feature space.
#    - Feature is igo with 2 channels per image.
#    - Level 1 (no downscale):
#      - Reference frame of length 7418 (3709 x 2C, 75W x 74H x 2C)
#      - 16 motion components
#      - 64 active appearance components (50.09% of original variance)
#    - Level 2 (downscale by 2):
#      - Reference frame of length 1846 (923 x 2C, 41W x 40H x 2C)
#      - 10 motion components
#      - 27 active appearance components (50.18% of original variance)
#    - Level 3 (downscale by 4):
#      - Reference frame of length 454 (227 x 2C, 24W x 23H x 2C)
#      - 7 motion components
#      - 11 active appearance components (51.56% of original variance)

# %%
fitting_results = []
# fit images
for j, i in enumerate(test_images):
    # obtain original landmarks
    gt_s = i.landmarks['PTS'].lms
    # generate perturbed landmarks
    s = fitter.perturb_shape(gt_s)
    # fit image
    fr = fitter.fit(i, s, gt_shape=gt_s) 
    # append fitting result to list
    fitting_results.append(fr)
    # print fitting information
    print 'Image: ', j
    print fr
# Out:
# Image:  0
# Initial error: 0.0723
# Final error: 0.0226
# Image:
#  1
# Initial error: 0.1098
# Final error: 0.0225
# Image:
#  2
# Initial error: 0.0842
# Final error: 0.2035
# Image:
#  3
# Initial error: 0.0871
# Final error: 0.0219
# Image:
#  4
# Initial error: 0.0964
# Final error: 0.1570

# %%
# %matplotlib inline

fitted_images = [fr.final_fitting for fr in fitting_results]
browse_images(fitted_images, group='fitted')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-e752d6ec742f> in <module>()
#       1 get_ipython().magic(u'matplotlib inline')
#       2
# ----> 3 fitted_images = [fr.final_fitting for fr in fitting_results]
#       4 browse_images(fitted_images, group='fitted')
#
# AttributeError: 'AAMMultilevelFittingResult' object has no attribute 'final_fitting'

# %% [markdown]
# ## 4. Fitting AAMs using `Menpo's` Supervised Descent (SD) framework
