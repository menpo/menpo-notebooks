# %% [markdown]
# # Constrained Local Models - Basics

# %% [markdown]
# -----

# %% [markdown]
# ## 1 Introduction

# %% [markdown]
# The aim of this notebook is to showcase showcase how one can build and fit CLMs to images using `Menpo`.
#
# Note that this notebook assumes that the user has previously gone through the AAMs Basics notebook and he/she is already familiar with the basics of `Menpo`'s Deformable Model Fitting framework explained in there.

# %% [markdown]
# ## 2 Loading data

# %%
path_to_lfpw = '/data/PhD/DataBases/'

# %%
import menpo.io as mio

training_images = []
# load landmarked images
for i in mio.import_images(path_to_lfpw + 'lfpw/trainset/*', verbose=True):
    # crop image
    i.crop_to_landmarks_proportion_inplace(0.1)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    training_images.append(i)
# Out:
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.html.widgets import interact, interactive

def browse_images(images, group=None, label='all'):
    n = len(images)
    def view_image(i):
        images[i].landmarks[group][label].view()
        plt.show()
    interact(view_image, i=(0,n-1))

# %%
browse_images(training_images, group='PTS')

# %% [markdown]
# ## 3 Build a CLM with default parameters

# %% [markdown]
# Building a CLM using `Menpo` can be done using a single line of code.

# %%
from menpo.fitmultilevel.clm import CLMBuilder

clm = CLMBuilder().build(training_images, verbose=True)
# Out:
# - Computing reference shape
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# ...

# %%
print clm
# Out:
# Constrained Local Model
#  - 811 training images.
#  - Gaussian pyramid with 3 levels and downscale factor of 1.1.
#    - Each level has a scaled shape model (reference frame).
#    - Patch size is 5W x 5H.
#    - Features were extracted at each pyramid level.
#    - Level 1 (no downscale):
#      - Feature is sparse_hog with 36 channels per image.
#      - 133 shape components (100.00% of variance)
#      - 68 linear_svm_predict classifiers.
#    - Level 2 (downscale by 1.1):
#      - Feature is sparse_hog with 36 channels per image.
#      - 133 shape components (100.00% of variance)
#      - 68 linear_svm_predict classifiers.
#    - Level 3 (downscale by 1.21):
#      - Feature is sparse_hog with 36 channels per image.
#      - 133 shape components (100.00% of variance)
#      - 68 linear_svm_predict classifiers.

# %% [markdown]
# ## 5 Fit the previous CLM

# %% [markdown]
# In `Menpo`, CLMs can be fitted to images by creating `Fitter` objects around them.
#
# One of the most popular algorithms for fitting CLMs is the `Regularized Landmark Mean-Shift` algorithm. In order to fit our CLM using this algorithm using `Menpo`, the user needs to define a `GradientDescentCLMFitter` object. This can be done again using a single line of code!!!

# %%
from menpo.fitmultilevel.clm import GradientDescentCLMFitter

fitter = GradientDescentCLMFitter(clm, n_shape=[3, 6, 12])

# %% [markdown]
# It is important to know that `GradientDescentCLMFitter` objects can be printed just like any other type `Fitter` object:

# %%
print fitter
# Out:
# Constrained Local Model Fitter
#  - Gradient-Descent RLMS
#  - Transform is OrthoPDM.
#  - 811 training images.
#  - Gaussian pyramid with 3 levels and downscale factor of 1.1.
#    - Each level has a scaled shape model (reference frame).
#    - Patch size is 5W x 5H.
#    - Features were extracted at each pyramid level.
#    - Level 1 (no downscale):
#      - Feature is sparse_hog with 36 channels per image.
#      - 16 motion components
#      - 68 linear_svm_predict classifiers.
#    - Level 2 (downscale by 1.1):
#      - Feature is sparse_hog with 36 channels per image.
#      - 10 motion components
#      - 68 linear_svm_predict classifiers.
#    - Level 3 (downscale by 1.21):
#      - Feature is sparse_hog with 36 channels per image.
#      - 7 motion components
#      - 68 linear_svm_predict classifiers.

# %% [markdown]
# Fitting a `GradientDescentCLMFitter` to an image is as simple as calling its `fit` method. Let's try it by fitting some images of the LFPW database test set!!!

# %%
import menpo.io as mio

# load test images
test_images = []
for i in mio.import_images(path_to_lfpw + 'lfpw/testset/*.png', max_images=5):
    # crop image
    i.crop_to_landmarks_proportion_inplace(0.5)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    test_images.append(i)

# %% [markdown]
# Note that for the purpose of this simple fitting demonstration we will just fit the first 5 images of the LFPW test set.

# %%
browse_images(test_images, group='PTS')

# %%
fitting_results = []
# fit images
for j, i in enumerate(test_images):
    # obtain original landmarks
    gt_s = i.landmarks['PTS'].lms
    # generate perturbed landmarks
    s = fitter.perturb_shape(gt_s)
    # fit image
    fr = fitter.fit(i, s, gt_shape=gt_s) 
    # append fitting result to list
    fitting_results.append(fr)
    # print fitting info
    print 'Image: ', j
    print 'Initial error: ', fr.initial_error
    print 'Final error: ', fr.final_error
# Out:
#  Image:  0
# Initial error:  0.0581860335171
# Final error:  0.0204601715594
# Image:
#  1
# Initial error:  0.0564915925634
# Final error:  0.0219144050006
# Image:
#  2
# Initial error:  0.0456119868443
# Final error:  0.0380454722826
# Image:
#  3
# Initial error:  0.0484001796819
# Final error:  0.0262875904183
# Image:
#  4
# Initial error:  0.107825004773
# Final error:  0.0632803639477

# %%
# %matplotlib inline

# visualize initialization
fitting_results[0].view_initialization(new_figure=True)

# visualize final fitting result
fitting_results[0].view_final_fitting(new_figure=True)
